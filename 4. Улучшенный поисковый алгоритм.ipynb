# %% [markdown]
# ###### Для части 1.

# %%
import sqlite3
import re
import pandas as pd
from pymystem3 import Mystem
m = Mystem()

# %% [markdown]
# ### 1. Как посмотреть вхождения в корпусе

# %%
db = sqlite3.connect('ALLP.db')
cur = db.cursor()
cur.execute('''SELECT author.band, song.songname, song.year, token.id, token.song_id, token.line, token.token, token.lem, token.pos, token.in_sent FROM token
            JOIN song ON song.id = token.song_id
        JOIN author ON author.id = song.author_id''')
tokens = cur.fetchall()
db.close()

# %%
tokens[10]
# Out:
# ('Loboda', 'Твои глаза', 2016, 1557, 18, 1, 'на', 'на', 'PR', 3)

# %%
def parsebase(tokens):
    tdictlist = []
    for token in tokens:
        tok = {}
        tok['artist']=token[0]
        tok['songname']=token[1]
        tok['year']=token[2]
        tok['id']=token[3]
        tok['song_id']=token[4]
        tok['line']=token[5]
        tok['token']=token[6]
        tok['lem']=token[7]
        tok['pos']=token[8]
        tok['in_sent']=token[9]
        tdictlist.append(tok)
        
    return tdictlist

# %%
basetokens = parsebase(tokens)

# %%
basetokens[1100]
# Out:
# {'artist': 'Loboda',
#  'songname': 'Я влюбилась',
#  'year': 2008,
#  'id': 2647,
#  'song_id': 28,
#  'line': 9,
#  'token': 'постель',
#  'lem': 'постель',
#  'pos': 'S',
#  'in_sent': 5}

# %% [markdown]
# #### Функции для обработки запроса

# %% [markdown]
# Предобработка для вхождений типа 'дождям', чтобы получить начальную форму. Мой алгоритм обрабатывает три типа запросов:<br>
# <ol><li>С двойными кавычками в начале - ищет полное совпадение с вводом (например, "дождям")</li><li>Без кавычек, начальная форма - ищет все вхождения токена в любых формах</li><li>По частеречному тегу (использованы теги <a href='https://yandex.ru/dev/mystem/doc/grammemes-values.html/'>mystem</a>)</li></ol>
# <i>Precheck</i> при помощи <i>checkform</i> заменяет неначальные формы не в кавычках в начальные формы для обработки по типу 2.<br><br>*Также обрабатываются запросы типа 'сосну+S', т.е. с неначальной формой (но можно и с начальной) и с частеречным тегом. Главное - <b>без</b> кавычек

# %%
def precheck(query):
    query.strip(' ')
    queries = query.split(' ')
    checked = []
    for item in queries:
        check = checkform(item)
        checked.append(check)
    return checked

# %%
def checkform(form):
    if not form.startswith(('A', 'C', 'I', 'N', 'P', 'S', 'V', '"')):
        lex = m.analyze(form)[0]['analysis'][0]['lex']
        if len(form.split('+'))==1:
            return lex
        else:
            return lex+'+'+form.split('+')[1]
            
    else:
        return form

# %% [markdown]
# В <i>search</i> подается список запросов, запросы проверяются в базе при помощи <i>checktype</i>. Первые вхождения проверяются отдельно от всех последующих, потому что без наличия первого невозможны другие.<br>NB в поиске я использую шаг от начальной формы не больше 2 (по заданию), но в целом шаг (step) можно делать сколько угодно удаленным.

# %%
def search(queries, tdictlist):  # по очереди итерируюсь, сколько нужно, убирая кандидатов на каждом шаге
    if len(queries)==1:
        last = checktype(queries[0], tdictlist, num=0) 
        if last:
            return last
    elif len(queries)==2:
        first = checktype(queries[0], tdictlist, num=0) 
        if first:
            last = checktype(queries[1], tdictlist, num=1, found=first)
            if last:
                return last
    else:
        first = checktype(queries[0], tdictlist, num=0)
        if first:
            second = checktype(queries[1], tdictlist, num=1, found=first)
            if second:
                last = checktype(queries[2], tdictlist, num=2, found=second)
                if last:
                    return last

# %%
def checktype(query, tdictlist, num=0, found=[]):
    
    foundtokens = []
    
    if num==0:
        if query.startswith('"'):
            for num, item in enumerate(tdictlist):
                if item['token']==query.strip('"'):
                    s_id = item['song_id']
                    token_id = item['id']
                    line = item['line']
                    foundtokens.append([num, s_id, line])  
        elif not query.startswith(('A', 'C', 'I', 'N', 'P', 'S', 'V')):
            if len(query.split('+'))==1:
                for num, item in enumerate(tdictlist):
                    if item['lem']==query:
                        s_id = item['song_id']
                        token_id = item['id']
                        line = item['line']
                        foundtokens.append([num, s_id, line])
            else:
                que, q_pos = query.split('+')
                for num, item in enumerate(tdictlist):
                    if item['lem']==que and item['pos'] == q_pos:
                        s_id = item['song_id']
                        token_id = item['id']
                        line = item['line']
                        foundtokens.append([num, s_id, line])
                
        else:
            for num, item in enumerate(tdictlist):
                if item['pos']==query:
                    s_id = item['song_id']
                    token_id = item['id']
                    line = item['line']
                    foundtokens.append([num, s_id, line])
        return foundtokens
    
    else:
        step = num
        nextf = []
        for item in found:
            num_inlist = item[0]
            s_id = item[1]
            if num_inlist+step<len(tdictlist):  # проверка, есть ли в списке с данными следующий элемент и что проверять
                if query.startswith('"'):
                    if tdictlist[num_inlist+step]['token']==query.strip('"'):
                            s2id = tdictlist[num_inlist+step]['song_id']
                            line = tdictlist[num_inlist+step]['line']
                            if s_id ==s2id:
                                item.append(line)
                                nextf.append(item)            
                elif not query.startswith(('A', 'C', 'I', 'N', 'P', 'S', 'V')):
                    if len(query.split('+'))==1:
                        if tdictlist[num_inlist+step]['lem']==query:
                            s2id = tdictlist[num_inlist+step]['song_id']
                            line = tdictlist[num_inlist+step]['line']
                            if s_id ==s2id:
                                item.append(line)
                                nextf.append(item)
                    else:
                        que, q_pos = query.split('+')
                        if tdictlist[num_inlist+step]['lem']==que and tdictlist[num_inlist+step]['pos'] == q_pos:
                            s2id = tdictlist[num_inlist+step]['song_id']
                            line = tdictlist[num_inlist+step]['line']
                            if s_id ==s2id:
                                item.append(line)
                                nextf.append(item)                        
                else:
                    if tdictlist[num_inlist+step]['pos']==query:
                        s2id = tdictlist[num_inlist+step]['song_id']
                        line = tdictlist[num_inlist+step]['line']
                        if s_id ==s2id:
                            item.append(line)
                            nextf.append(item)
        return nextf

# %% [markdown]
# При помощи <i>index2df</i> индексы вхождений, полученные на предыдущем этапе, превращаются в строки с вхождениями

# %%
def index2df(indexlist, tdictlist):
    fordf = []
    for item in indexlist:
        numfromlist = item[0]
        s_id = item[1]
        line = item[2]
        string = []
        for token in tdictlist[numfromlist-25:]:
            if token['song_id']==s_id:
                if token['line']==line or token['line']==line+1:
                    string.append(token['token'])
        songitems = []
        songitems.append(tdictlist[numfromlist]['artist'])
        songitems.append(tdictlist[numfromlist]['songname'])
        songitems.append(tdictlist[numfromlist]['year'])
        songitems.append(' '.join([item for item in string]))
        fordf.append(songitems)
    return fordf

# %% [markdown]
# Финальный датафрэйм

# %%
def getdf(query, tdictlist):
    checked = precheck(query)
    lists = search(checked, tdictlist)
    if lists:
        fordf = index2df(lists, tdictlist)
        df = pd.DataFrame(fordf, columns=['artist', 'songname', 'year', 'lyrics'])
        return df

# %% [markdown]
# #### Примеры

# %%
getdf('"Нас" PART догонят+V', basetokens)  # сочетание всех типов
# Out:
#      artist        songname  year  \
# 0  t.A.T.u.  Нас Не Догонят  2001
# 1  t.A.T.u.  Нас Не Догонят  2001
#
#                                               lyrics
# 0       Нас не догонят Нас не догонят нас не догонят
# 1  Нас не догонят нас не догонят Только скажи дал...

# %%
getdf('CONJ SPRO "влюблен"', basetokens)
# Out:
#       artist         songname  year  \
# 0  Иван Дорн  Северное сияние  2012
#
#                                               lyrics
# 0  День был холодный а я влюблен Нас было трое жа...

# %%
getdf('A S V', basetokens)
# Out:
#              artist                songname  year  \
# 0            Loboda              Твои глаза  2016
# 1            Loboda               Случайная  2017
# 2            Loboda             40 градусов  2012
# 3            Loboda       Потому, что люблю  2005
# 4            Loboda            Чёрный ангел  2005
# ...             ...                     ...   ...
# 1055  Потап и Настя         У нас на районе  2009
# 1056  Потап и Настя         У нас на районе  2009
# 1057  Потап и Настя       Позвони своей зае  2009
# 1058  Потап и Настя  Чипсы, чиксы, лавандос  2009
# 1059  Потап и Настя                  Качаем  2009
#
#                                                  lyrics
# 0     Неловкое молчание повисло Слишком слишком близ...
# 1     Простые ответы увидимся снова Заклеив конверты...
# 2     Его неземные слова допила до дна Держи меня но...
# 3            Слепая тоска несет Измученный крик надежды
# 4     Чёрным ангелом в ночи тихим ветром постучи Ты ...
# ...                                                 ...
# 1055  А по району ходят бродят классные цыпочки Корч...
# 1056                   Дворовыми басами завывают с нами
# 1057  Комната пустая шторы закрываю Больше не вернёш...
# 1058  Виртуальные кенты говорят что я лох Потому что...
# 1059  Мы посидим поговорим с ней о чем то не важном ...
#
# [1060 rows x 4 columns]

# %%
getdf('клубом дымом', basetokens)
# Out:
#         artist             songname  year  \
# 0         Децл  Меломанов плейлисты  2018
# 1  Bad Balance      Городская тоска  1996
#
#                                               lyrics
# 0  Клубы дыма стробоскопы лазеры прожектора Здесь...
# 1  Под густыми клубами дыма улицы темнеют Город п...

# %%
getdf('"Я" "любила"', basetokens)
# Out:
#    artist songname  year                      lyrics
# 0  Винтаж      Ева  2009  Я любила тебя Беги от меня

# %%
getdf('"Я" "любил"', basetokens)
# Out:
#              artist          songname  year  \
# 0  Тима Белорусских  Привычка убегать  2019
# 1        Скриптонит           Зеркала  2017
#
#                                               lyrics
# 0                         Я любил бы их всех их всех
# 1  Я любил в этом страсть а не пошлость Курица ра...

# %%
getdf('я "любил"', basetokens)
# Out:
#              artist             songname  year  \
# 0  Тима Белорусских     Привычка убегать  2019
# 1        Скриптонит              Зеркала  2017
# 2             Баста            Вселенная  2013
# 3   Валерий Меладзе  Потерян И Не Найден  2014
# 4   Валерий Меладзе  Потерян И Не Найден  2014
#
#                                               lyrics
# 0                         Я любил бы их всех их всех
# 1  Я любил в этом страсть а не пошлость Курица ра...
# 2  Но я любил так будто клялся будто дал обет Пру...
# 3  А я любил ее мучительно и нежно каждый день те...
# 4  Ведь я любил ее мучительно и нежно каждый день...

# %%
getdf('я+SPRO люблю', basetokens)
# Out:
#                artist          songname  year  \
# 0              Loboda      Чёрный ангел  2005
# 1              Loboda      Чёрный ангел  2005
# 2              Loboda      Чёрный ангел  2005
# 3              Loboda  Там, за облаками  2005
# 4           Егор Крид           Потрачу  2017
# ..                ...               ...   ...
# 68             Винтаж     Kill.Dim.Bil.  2007
# 69  Наталья Ветлицкая       Пусть будет  1994
# 70                ДДТ       В ресторане  2003
# 71          Банд’Эрос  Танцуй, Рублевка  2006
# 72          Банд’Эрос  Танцуй, Рублевка  2006
#
#                                                lyrics
# 0   Я люблю тебя я люблю тебя я люблю тебя Отпусти...
# 1   Я люблю тебя я люблю тебя я люблю тебя Отпусти...
# 2   Я люблю тебя я люблю тебя я люблю тебя Отпусти...
# 3   Теперь ты знаешь как я люблю Меня возьми меня ...
# 4   Люблю и ненавижу я люблю и ненавижу С тобой я ...
# ..                                                ...
# 68                        Просто дура просто я любила
# 69  Что ты меня любишь и ждёшь Мне сегодня просто ...
# 70  Прости меня я люблю твои овалы и тени И вдруг ...
# 71  Я люблю эти улицы с грязным лицом Моё место зд...
# 72  Таких как я любят сучки в стиле ти эн джи Кред...
#
# [73 rows x 4 columns]

# %%
getdf('спит S', basetokens)
# Out:
#               artist                  songname  year  \
# 0          Егор Крид              Папина дочка  2015
# 1         Shortparis                   Страшно  2018
# 2         Shortparis                  Поломало  2019
# 3         Shortparis          Отвечай за слова  2019
# 4         Shortparis          Отвечай за слова  2019
# 5         Shortparis          Отвечай за слова  2019
# 6         Shortparis             Раз, два, три  2017
# 7              Грибы                      Копы  2016
# 8              Баста            Раз и навсегда  2006
# 9            Дельфин                       713  2018
# 10             Каста                    Сказка  2002
# 11            Тимати                     Зомби  2006
# 12          t.A.T.u.               Я Твой Враг  2001
# 13            МакSим                     Птицы  2009
# 14           АукцЫон               Спи, солдат  1994
# 15               ДДТ                    Родина  1992
# 16               ДДТ                      Ночь  1992
# 17       Bad Balance                Аль Капоне  2007
# 18        Руки Вверх                     Малыш  1997
# 19   Валерий Меладзе                      Вера  1996
# 20           Колибри         Фудзи еще не спит  1991
# 21      Поп-механика  Вот сверчок, вот стручок  1996
# 22  Татьяна Буланова                  Как жаль  1992
# 23               ДДТ           Рабочий квартал  2002
#
#                                                lyrics
# 0   Я обожаю то как она спит ноги руки на мне это ...
# 1                           Спят сыновья Молчит семья
# 2                               Пока спала Беда текла
# 3   Спит пространство двора и спит детвора Тихо и ...
# 4   Спит пространство двора и спит детвора Тихо и ...
# 5   Спит рабочий и с ним вторая жена Спит как будт...
# 6                  В ванной спит жених В женщине дитя
# 7   Это принципиально нету времени спать Руки в во...
# 8   Я мог не спать ночами находясь в тумане Я кури...
# 9   Спящих людей которых не знаю Они не проснутся ...
# 10  Он тихо вышел из замка мимо спящей стражи Нару...
# 11  Мы спим днем пока асфальт плавится Ночью из кл...
# 12  Город не спит время стоит С кем твои игры сегодня
# 13  Спите дети сны в лукошке Под подушкой тихо спрячу
# 14                     Спи солдат От темна и до темна
# 15  Спящая красавица Из-под черных рубах рвется кр...
# 16  Спите люди всей столицы вы и звери вы и птицы ...
# 17  Город не спящий баксы хрустящие Кровь на асфал...
# 18           Мне пора спать Папа сказал идти спать да
# 19  Спит проводник спят хмельные соседи Я все усну...
# 20        А Фудзи ещё не спит А Фудзи ещё не ложилась
# 21  Спит хомяк спешит варяг боцман дует в рог Гей ...
# 22  Уже спокойно сплю ночами Осталась за спиной черта
# 23  В рабочем квартале не спят рабочий квартал нож...

# %%
getdf('S петь', basetokens)
# Out:
#                  artist                      songname  year  \
# 0                Loboda                    Твои глаза  2016
# 1                Loboda                       Дай мне  2005
# 2             монеточка                            90  2018
# 3             монеточка                  Козырный туз  2016
# 4      Тима Белорусских                     Песня-SOS  2019
# 5                  FACE                         САЛАМ  2018
# 6            Shortparis                        Любовь  2017
# 7            Shortparis                        Любовь  2017
# 8            Shortparis                        Любовь  2017
# 9            Shortparis                        Любовь  2017
# 10           Shortparis                 Жизнь за царя  2019
# 11            Ленинград                      Чемпионы  2018
# 12                  ЛСП               Мне скучно жить  2014
# 13                  ЛСП            Лабиринт отражений  2017
# 14                Хаски                     Бэнг Бэнг  2015
# 15                Баста                         Урбан  2010
# 16                 Децл              No Name, No Game  2017
# 17         Мумий Тролль                       Девочка  1997
# 18         Мумий Тролль                       Девочка  1997
# 19         Мумий Тролль              Делай Меня Точно  1990
# 20                Сплин                  Дочь самурая  2012
# 21               Тимати                           АМГ  2019
# 22                 Ёлка             Мобильный телефон  2007
# 23                 Ёлка                   Доброе утро  2007
# 24         Агата Кристи               Сказочная тайга  1995
# 25         Агата Кристи                        Ураган  1997
# 26             Аквариум                    Юрьев День  1994
# 27             Аквариум                    Юрьев День  1994
# 28             Аквариум                    Юрьев День  1994
# 29             Аквариум                    Юрьев День  1994
# 30             Аквариум                 Центр циклона  1996
# 31  Гражданская оборона    Невыносимая Легкость Бытия  1997
# 32  Гражданская оборона               Пой, революция!  1997
# 33  Гражданская оборона               Пой, революция!  1997
# 34          Bad Balance                        Я лечу  2001
# 35              Кар-Мэн                    Эй, ухнем!  1990
# 36           Руки Вверх                         Малыш  1997
# 37           Руки Вверх                       Песенка  1998
# 38    Наталья Ветлицкая            Аквалангисты любви  1994
# 39      Валерий Меладзе                   Белые Птицы  2015
# 40              Колибри  О чем поет тропическая птица  1991
# 41              Колибри                      Прогулка  1992
# 42              Колибри                      Прогулка  1992
# 43              Колибри                      Прогулка  1992
# 44         Поп-механика      Вот сверчок, вот стручок  1996
# 45     Татьяна Буланова                      Шарманка  1999
# 46     Татьяна Буланова                      Шарманка  1999
# 47                  ДДТ                        180 см  2002
# 48        Леонид Агутин                          Муха  1995
# 49             А-Студио                      Серенада  1994
# 50              Бумбокс                           TNT  2008
#
#                                                lyrics
# 0
# 1   Суета пело тело мое и душа Но сказала я Стоп н...
# 2   Ведь только Ласковый Май пел по радио А я живу...
# 3   Озверели оборзели в интернете песни пели Ах пр...
# 4   Благодаря тебе моя душа поет Больше не надо ни...
# 5   Заряжен укороченный АК поёт как флейта Все мои...
# 6                                  Водой Пой дева пой
# 7                             Пой дева пой Он с тобой
# 8               Ты здесь прикройся рукой Пой сука пой
# 9                              Пой сука пой Что живой
# 10                И женщина поет Станем станем старше
# 11  Кто там песню пел о Рамзане Наши пацаны рвут ш...
# 12  И мы бредни поём чтоб забыть неизменный наёб Т...
# 13  группа Корни пели Жить ещё не поздно умирать т...
# 14  И мёртвый человек поёт тебе о том что мёртвый ...
# 15  Стать бесхребетной мразью Петь на праздниках п...
# 16  Вам бы сука петь тюремные романсы На Арме под ...
# 17  Пьет дpугих девчонок сок поет им песни Может б...
# 18  Пьёт других девчонок сок поёт им песни Hо толь...
# 19  Выключай скорей всю эту дребедень Поют реактив...
# 20  Берег молчит море поёт Возьми себя в руки дочь...
# 21  Мот пел что он на дне а я и есть дно И пусть р...
# 22  Телефон поёт мигает и блестит будто говорит О ...
# 23  Великолепный мир поёт Под эту мелодию страна в...
# 24  На ночь поют нам большие деревья Черные сказки...
# 25                Дорога в ад пой ветер нам Гори душа
# 26  А один из нас сделал рыцарский жест Пой песню пой
# 27  Пой песню пой Теперь он стал золотом в списках...
# 28  А ты пой песню пой Твой певец исчез в глубине ...
# 29     Лучше пой песню пой Вчера пионеры из монастыря
# 30  Ангелы пели в небесах А я проснулся в черном теле
# 31  Звезда чадит звезда поёт звезда горит Шальная ...
# 32                      Небо поёт В небе пылает песня
# 33                  В небе пылает песня Пой революция
# 34  Труба наполненная ветром поет Сантиметр метр к...
# 35                     Лесорубы песенку поют Эй ухнем
# 36  А я играю а я танцую и песенки пою Песенка про...
# 37  Все мои друзья поют со мною вместе Может быть ...
# 38  Мы стоим с тобой у берега любви Поёт в ночи пр...
# 39    И по тебе моя душа поёт и плачет поровну Припев
# 40  Очём поёт тропическая птица Что краски дня ей ...
# 41  Песню поем только поем а больше ничего Ты всех...
# 42  А птицы поют больше никто уснуть не может За л...
# 43          Мы просто идем песню поем а больше ничего
# 44  Вот сверчок вот стручок вот мой отчий дом Поёт...
# 45  Тихо шарманка поёт на улице Старый шарманщик н...
# 46  Пой шарманка пой о любви слепой И о том как мы...
# 47  И девять месяцев пела вода А потом обратилась ...
# 48  Все крылышки мыла и песенки пела А он не любил...
# 49  Нас обвенчал под крышей старого зонта Пела ты ...
# 50  Птички поют поют несут домой смекту Из отдела ...

# %%
getdf('фейсбук', basetokens)
# Out:
#       artist      songname  year  \
# 0  монеточка     Пост-пост  2018
# 1  монеточка  Козырный туз  2016
# 2  Ленинград          Вояж  2017
#
#                                               lyrics
# 0  Без аккаунта в фейсбуке без диплома и паспорта...
# 1  За все репосты и подписки в фейсбуке Коли мужи...
# 2  Чтобы фоточки в Фейсбуке залепить как говоритс...
